# %% [markdown]
# # Obtendo cotações históricas de ativos.

# %%
import pandas_datareader as web
import pandas as pd

plt.style.use('fivethirtyeight')

# %%
#Obtendo a cotação
df = web.DataReader('BTCUSD=X', data_source='yahoo', start='2012-01-01', end='2020-12-23') 
#dataframe da cotação
df
# Out:
#                     High           Low          Open         Close  \
# Date
# 2012-01-02      4.800000      5.470000      5.268000      5.217000
# 2012-01-03      4.650000      5.290000      5.217000      4.881000
# 2012-01-04      4.751000      5.700000      4.881000      5.574000
# 2012-01-05      5.574000      7.220000      5.574000      6.948000
# 2012-01-06      6.126000      7.210000      6.948000      6.697000
# ...                  ...           ...           ...           ...
# 2020-12-01  18321.931641  19845.994141  19633.751953  18803.000000
# 2020-12-02  18347.714844  19308.337891  18801.728516  19201.082031
# 2020-12-03  18925.773438  19566.177734  19205.912109  19445.417969
# 2020-12-04  18697.179688  19511.396484  19446.966797  18699.767578
# 2020-12-23  23776.259766  11057.008789  23783.027344  23776.259766
#
#                  Volume     Adj Close
# Date
# 2012-01-02   36035700.0      5.217000
# 2012-01-03   61917000.0      4.881000
# 2012-01-04   68871700.0      5.574000
# 2012-01-05  113062300.0      6.948000
# 2012-01-06  148132700.0      6.697000
# ...                 ...           ...
# 2020-12-01          0.0  18803.000000
# 2020-12-02          0.0  19201.082031
# 2020-12-03          0.0  19445.417969
# 2020-12-04          0.0  18699.767578
# 2020-12-23          0.0  23776.259766
#
# [2331 rows x 6 columns]

# %%
# número de linhas e colunas no conjunto de dados
df.shape
# Out:
# (2331, 6)

# %%
#Visualize o histórico do preço de fechamento
plt.figure(figsize=(16,8))
plt.title('Preços de Fechamentos históricos')
plt.plot(df['Close'])
plt.xlabel('Data',fontsize=18)
plt.ylabel('Preço em USD ($)',fontsize=18)
plt.show()
